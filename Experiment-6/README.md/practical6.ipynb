# %% [markdown]
# <a href="https://colab.research.google.com/github/AsitSrivastava06/Basics-of-Pyhton/blob/main/practical6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Experiment-6
# ##NMAE-ASIT KUMAR SRIVASTAVA
# #PRN-25070123026
# #BATCH-A2
# #TITLE-Study of Conditional statements in python

# %%
#1a.Check whether a number is positive , negative
num = int(input("Enter a number: "))
if(num>0):
  print(num,"is positive")
else:
  print(num,"is negative")
# Out:
# Enter a number: 9
# 9 is positive

# %%
#1b. Check whether a number is positive , negative or zero
num = int(input("Enter a number: "))
if(num>0):
  print(num,"is positive")
elif(num<0):
  print(num,"is negative")
else:
    print("number is zero")
# Out:
# Enter a number: 2
# 2 is positive

# %%
#2. Check whether number is even or odd
num = int(input("Enter a number: "))
if(num%2==0):
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number: 5
# Odd

# %%
# largest of two number
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
if(num1>num2):
  print(num1,"is largest")
else:
  print(num2,"is largest")
# Out:
# Enter a number: 3
# Enter a number: 4
# 4 is largest

# %%
# Largest number among three
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
num3 = int(input("Enter a number: "))
if(num1>=num2 and num1>=num3):
  print(num1,"is largest")

elif(num2>=num1 and num2>=num3):
  print(num2,"is largest")
else:
  print(num3,"is largest")
# Out:
# Enter a number: 3
# Enter a number: 68
# Enter a number: 76
# 76 is largest

# %%
# Get input from user for 5 subjets and find average
# calculate grade using if-elif-else
sub1 = int(input("Enter marks of subject 1: "))
sub2 = int(input("Enter marks of subject 2: "))
sub3 = int(input("Enter marks of subject 3: "))
sub4 = int(input("Enter marks of subject 4: "))
sub5 = int(input("Enter marks of subject 5: "))
avg = sum([sub1,sub2,sub3,sub4,sub5])/5
print("Average marks is: ",avg)
if(avg>90):
  print("Grade O")
elif(90>avg and avg>80):
  print("Grade A+")
elif(avg<80 and avg>70):
  print("Grade A")
elif(avg<70 and avg>60):
  print("Grade B+")
elif(avg<60 and avg>50):
  print("Grade B")
elif(avg>30):
  pint("pass")
elif(avg<30):
  print("fail")
# Out:
# Enter marks of subject 1: 90
# Enter marks of subject 2: 90
# Enter marks of subject 3: 98
# Enter marks of subject 4: 78
# Enter marks of subject 5: 80
# Average marks is:  87.2
# Grade A+

# %%
#check whether a year is leap year
year = int(input("Enter a year: "))
if(year%400 == 0) or (year%4==0 and year%100!=0):
  print(year,"is a leap year")
else:
  print(year,"is not a leap year")
# Out:
# Enter a year: 2020
# 2020 is a leap year

# %%
# python pogram to check i a  date is valid and print the incremented date if it is valid
date = input("Enter the date in format {dd/mm/yyyy} ")

dd, mm, yy = date.split("/")
dd = int(dd)
mm = int(mm)
yy = int(yy)

if mm < 1 or mm > 12:
    print("Date is invalid.")

else:
    if mm in (1, 3, 5, 7, 8, 10, 12):
        max1 = 31
    elif mm in (4, 6, 9, 11):
        max1 = 30
    else:  # February
        if (yy % 4 == 0 and yy % 100 != 0) or (yy % 400 == 0):
            max1 = 29
        else:
            max1 = 28
    if dd < 1 or dd > max1:
        print("Date is invalid.")

    else:
        # Increment date
        if dd == max1 and mm != 12:
            dd = 1
            mm += 1
        elif dd == 31 and mm == 12:
            dd = 1
            mm = 1
            yy += 1
        else:
            dd += 1

        print(f"The incremented date is: {dd:02d}/{mm:02d}/{yy}")
# Out:
# Enter the date in format {dd/mm/yyyy} 12/12/25
# The incremented date is: 13/12/25

# %%
#9.Salary Calculation with Allowances

basic = int(input("enter the salary", ))
if basic<=10000 :
  gross = basic + (basic*20)/100 + (basic*80)/100
  print("Gross Salary:",gross)
elif basic<=20000 :
  gross = basic + (basic*25)/100 + (basic*90)/100
  print("Gross Salary:",gross)
else :
   gross = basic + (basic*30)/100 + (basic*95)/100
   print("Gross Salary:",gross)
# Out:
# enter the salary50000
# Gross Salary: 112500.0

# %%
#10.Write a Python Program to calculate income tax based on annual income:

salary = int(input("Enter your salary: "))

if salary <= 250000:
    tax = 0

elif salary <= 500000:
    tax = (salary - 250000) * 0.05

elif salary <= 1000000:
    tax = (250000 * 0.05) + (salary - 500000) * 0.20

else:
    tax = (250000 * 0.05) + (500000 * 0.20) + (salary - 1000000) * 0.30

print("Tax is:", tax)
# Out:
# Enter your salary: 100000
# Tax is: 0
