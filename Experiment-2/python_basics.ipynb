# %% [markdown]
# <a href="https://colab.research.google.com/github/AsitSrivastava06/Basics-of-Pyhton/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name-Asit Kumar Srivastava
# #PRN-2507023026
# #Batch-A2
# #Unit-1

# %% [markdown]
# ##Basic Programs-Experiment-1

# %%
#First Pyhton Program / String
print("Hello,Welcome to Python Programming")
# Out:
# Hello,Welcome to Python Programming

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
#Commment
#this is comment
print("Hello,Welcome")
# Out:
# Hello,Welcome

# %%
print("Hello World!")
print("Have a Good day")
print("Learning python is fun!")
# Out:
# Hello World!
# Have a Good day
# Learning python is fun!

# %%
print("Hello"); print("how are you ?"); print("Bye bye!")
# Out:
# Hello
# how are you ?
# Bye bye!

# %%
# Print numbers
a=3
print(a)
print(358)
print(500.200)
# Out:
# 3
# 358
# 500.2

# %%
# Case-Sensitive
a=4
A= "Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
#Many values to Multiple variables
x,y,z= "Orange","Banana","Cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# Banana
# Cherry

# %%
# Basic Arithmetic Operations
a =10
b=5
print("Addition =", a+b)
# Out:
# Addition = 15

# %%
# Understanding Data Types
x=10
y=3.14
z = "Python"
A= True
C = 3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# Taking Input form user
name = input("Enter your Name : ")
age = int(input("Enter your age : "))
print("Name :", name)
print("Age:",age)
# Out:
# Enter your Name : Asit
# Enter your age : 19
# Name : Asit
# Age: 19

# %%
s1 = float(input("Marks of s1 : "))
s2 = float(input("Marks of s2 : "))
s3 = float(input("Marks of s3 : "))
s4 = float(input("Marks of s4 : "))
s5 = float(input("Marks of s5 : "))


print("sum =", s1+s2+s3+s4+s5)
print("Average = ",(s1+s2+s3+s4+s5)/5)
# Out:
# Marks of s1 : 20
# Marks of s2 : 20
# Marks of s3 : 20
# Marks of s4 : 20
# Marks of s5 : 20
# sum = 100.0
# Average =  20.0

# %%
# Area of circle
r = float(input("enter radius : "))
print("area =",3.14*r*r)
# Out:
# enter radius : 5
# area = 78.5

# %%
l = float(input("enter length : "))
b = float(input("enter breadth : "))

print("Area of rectangle = ", l*b)

# %%
l = float(input("enter length : "))
b = float(input("enter breadth : "))

print("Perimeter of rectangle = ", 2*(l+b))
# Out:
# enter length : 10
# enter breadth : 5
# Perimeter of rectangle =  30.0

# %%
#Python Booleans
print(10>9)
print(10 == 9)
print(10<9)
# Out:
# True
# False
# False

# %%
# Simple calculator
a = int(input("enter fisrt number :"))
b = int(input("enter second number :"))
print("addition =",a+b)
print("subtraction =",a-b)
print("multiplication =",a*b)
print("division =",a/b)
# Out:
# enter fisrt number :10
# enter second number :2
# addition = 12
# subtraction = 8
# multiplication = 20
# division = 5.0

# %%
+
